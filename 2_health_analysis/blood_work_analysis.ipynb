# %%
from dotenv import load_dotenv

from langchain_google_genai import ChatGoogleGenerativeAI

load_dotenv()

llm=ChatGoogleGenerativeAI(model="gemini-2.5-flash")
print("all good")
# Out:
# all good

# %%
with open("blood_work.txt","r") as f:
    blood_report=f.read();

print(blood_report[:2000])
# Out:
# Patient: Rajesh Sharma, Age 48, Male
# Date: May 7, 2026
#
# COMPLETE BLOOD COUNT (CBC)
#
# Hemoglobin: 15.1 g/dL (Normal: 13.5â€“17.5)
# Hematocrit: 44% (Normal: 41â€“53%)
# WBC: 6.8 x10^3/uL (Normal: 4.5â€“11.0)
# Platelets: 220 x10^3/uL (Normal: 150â€“400)
#
# LIPID PANEL
#
# Total Cholesterol: 238 mg/dL (Normal: <200)
# LDL Cholesterol: 162 mg/dL (Normal: <100)
# HDL Cholesterol: 36 mg/dL (Normal: >40)
# Triglycerides: 188 mg/dL (Normal: <150)
#
# METABOLIC PANEL
#
# Glucose (Fasting): 92 mg/dL (Normal: 70â€“99)
# HbA1c: 5.3% (Normal: <5.7%)
# Creatinine: 1.0 mg/dL (Normal: 0.7â€“1.3)
# eGFR: 82 mL/min (Normal: >60)
#
# LIVER FUNCTION
#
# ALT: 28 U/L (Normal: 7â€“40)
# AST: 25 U/L (Normal: 10â€“40)
# Bilirubin Total: 0.8 mg/dL (Normal: 0.2â€“1.2)
#
# Reviewing Physician: Dr. Priya Nair

# %%
extraction_prompt= f"""
you are a medical data extraction assistant.

from the blood report below,extract all test values and classify each one as HIGH,LOW or NORMAL
based on reference ranges provided in the report.

format your response in JSON format as:
[Test Name: value,
  Status: HIGH/LOW/NORMAL
  Reference:range]

Blood Report:
{blood_report}
"""

extraction_response=llm.invoke(extraction_prompt)
extracted_values=extraction_response.text

print("=== STAGE 1: EXTRACTED VALUES===")
print(extracted_values)
# Out:
# === STAGE 1: EXTRACTED VALUES===
# ```json
# [
#   {
#     "Test Name": "Hemoglobin",
#     "Status": "NORMAL",
#     "Reference": "13.5â€“17.5 g/dL"
#   },
#   {
#     "Test Name": "Hematocrit",
#     "Status": "NORMAL",
#     "Reference": "41â€“53%"
#   },
#   {
#     "Test Name": "WBC",
#     "Status": "NORMAL",
#     "Reference": "4.5â€“11.0 x10^3/uL"
#   },
#   {
#     "Test Name": "Platelets",
#     "Status": "NORMAL",
#     "Reference": "150â€“400 x10^3/uL"
#   },
#   {
#     "Test Name": "Total Cholesterol",
#     "Status": "HIGH",
#     "Reference": "<200 mg/dL"
#   },
#   {
#     "Test Name": "LDL Cholesterol",
#     "Status": "HIGH",
#     "Reference": "<100 mg/dL"
#   },
#   {
#     "Test Name": "HDL Cholesterol",
#     "Status": "LOW",
#     "Reference": ">40 mg/dL"
#   },
#   {
#     "Test Name": "Triglycerides",
#     "Status": "HIGH",
#     "Reference": "<150 mg/dL"
#   },
#   {
#     "Test Name": "Glucose (Fasting)",
#     "Status": "NORMAL",
#     "Reference": "70â€“99 mg/dL"
#   },
#   {
#     "Test Name": "HbA1c",
#     "Status": "NORMAL",
#     "Reference": "<5.7%"
#   },
#   {
#     "Test Name": "Creatinine",
#     "Status": "NORMAL",
#     "Reference": "0.7â€“1.3 mg/dL"
#   },
#   {
#     "Test Name": "eGFR",
#     "Status": "NORMAL",
#     "Reference": ">60 mL/min"
#   },
#   {
#     "Test Name": "ALT",
#     "Status": "NORMAL",
#     "Reference": "7â€“40 U/L"
#   },
#   {
#     "Test Name": "AST",
#     "Status": "NORMAL",
#     "Reference": "10â€“40 U/L"
#   },
#   {
#     "Test Name": "Bilirubin Total",
#     "Status": "NORMAL",
#     "Reference": "0.2â€“1.2 mg/dL"
#   }
# ]
# ```

# %%
diet_prompt=f"""

you are a clinical nutritionist specialising in Indian dietary habits.

Based on blood work analysis below,write:
1.short health summary in 3 lines explaining the patients condition in simple language
2.a short,practical Indian diet plan having only two sections (1)Foods to avoid (2)Foods to eat more of.
Do not include any other sections in diet plan.

Blood Work Analysis:
{extracted_values}

"""

diet_response=llm.invoke(diet_prompt)

print("=== STAGE 2:HEALTH SUMMARY & DIET PLAN===")
print(diet_response.text)
# Out:
# === STAGE 2:HEALTH SUMMARY & DIET PLAN===
# Here is your health summary and practical Indian diet plan:
#
# ---
#
# **1. Short Health Summary:**
#
# Your blood work indicates an unhealthy lipid profile. This means your "bad" cholesterol (LDL) and triglycerides are high, while your "good" cholesterol (HDL) is low. These findings suggest an increased risk for heart disease, which can be significantly improved with dietary and lifestyle changes.
#
# ---
#
# **2. Short, Practical Indian Diet Plan:**
#
# **(1) Foods to avoid:**
# *   Deep-fried items like samosas, pakoras, puri, vada, and jalebi, along with excessive use of ghee, butter, or dalda (vanaspati).
# *   Processed foods, packaged snacks (namkeens, biscuits), bakery items, and sugary sweets (mithai) and drinks.
# *   Full-fat dairy products and fatty cuts of red meat; also limit creamy, rich gravies.
# *   Refined grains like white bread and maida-based products (e.g., naan, bhature).
#
# **(2) Foods to eat more of:**
# *   Whole grains like whole wheat roti, brown rice, oats, and millets (ragi, bajra, jowar) and all types of dals and legumes (rajma, chole, moong, masoor).
# *   Plenty of fresh vegetables (especially leafy greens) and seasonal fruits daily.
# *   Lean proteins such as skinless chicken, fish (if non-vegetarian), eggs, and low-fat dairy.
# *   Healthy fats from nuts (almonds, walnuts), seeds (flaxseeds, chia seeds), and moderate use of healthy cooking oils like mustard, groundnut, or olive oil.
